# %%
import pandas as pd

# %%
insurance = pd.read_csv("insurance.csv")
insurance.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
from autoviz.AutoViz_Class import AutoViz_Class
AV = AutoViz_Class()
insurance_report = AV.AutoViz("insurance.csv")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from autoviz.AutoViz_Class import AutoViz_Class
#       2 AV = AutoViz_Class()
#       3 insurance_report = AV.AutoViz("insurance.csv")
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/autoviz/__init__.py:3
#       1 name = "autoviz"
#       2 from .__version__ import __version__, __holo_version__
# ----> 3 from .AutoViz_Class import AutoViz_Class
#       4 from .AutoViz_Class import data_cleaning_suggestions
#       5 from .AutoViz_Class import FixDQ
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/autoviz/AutoViz_Class.py:29
#      27 from pandas_dq import Fix_DQ, dq_report
#      28 ##########################################################################################
# ...

# %%
report = AV.AutoViz("insurance.csv", chart_format="bokeh", depVar="charges")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 report = AV.AutoViz("insurance.csv", chart_format="bokeh", depVar="charges")
#
# NameError: name 'AV' is not defined
