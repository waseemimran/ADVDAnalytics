# %%
# importing the usual needed modules
import pandas as pd
import numpy as np

# %%
drug = pd.read_csv("drug.csv")
drug.head()
# Out:
#    Age Sex      BP Cholesterol  Na_to_K   Drug
# 0   23   F    HIGH        HIGH   25.355  DrugY
# 1   47   M     LOW        HIGH   13.093  drugC
# 2   47   M     LOW        HIGH   10.114  drugC
# 3   28   F  NORMAL        HIGH    7.798  drugX
# 4   61   F     LOW        HIGH   18.043  DrugY

# %%
import sweetviz as sv

# Analyzing the dataset
drug_sweetviz_report = sv.analyze(drug)

# Show the report in an HTML file
drug_sweetviz_report.show_html("drug_sweetviz_report.html")
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
# Report drug_sweetviz_report.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
# Dataset has 200 rows, 6 features (4 categorical, 2 numerical), and no missing values.
# Age: Min 15, Max 74, Avg 44.3, Median 45, STD 16.5, Distinct 57 (28%).
# Sex: 2 categories (M, F) ~50% each.
# BP: 3 categories – High (~40%), Low (~30%), Normal (~30%).
# Cholesterol: 2 categories – High, Normal (~50% each).
# Na_to_K: Min 6.3, Max 38.2, Avg 16.1, Median 13.9, STD 7.22, Distinct 198 (99%).
# Drug: 5 categories – DrugY (~40%), DrugX, DrugA, DrugC, DrugB (smaller shares).
# Distribution: Age is fairly spread, Na_to_K skewed right, categorical variables well balanced.

#Overall: demographic features are balanced, but drug choice seems influenced by Na_to_K and BP.
