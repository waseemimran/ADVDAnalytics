# %%
# importing the usual needed modules
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
insurance = pd.read_csv("insurance.csv")
insurance.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
from ydata_profiling import ProfileReport

report = ProfileReport(insurance, title='insurance Report', explorative=True)

report.to_file('insurance_report.html')
# Out:
#             <div>
#                 <ins><a href="https://ydata.ai/register">Upgrade to ydata-sdk</a></ins>
#                 <p>
#                     Improve your data and profiling with ydata-sdk, featuring data quality scoring, redundancy detection, outlier identification, text validation, and synthetic data generation.
#                 </p>
#             </div>
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
import webbrowser
webbrowser.open('insurance_report.html')
# Out:
# True

# %%
# Alert
# Duplicates: The dataset contains 1 duplicate row (0.1%), which may slightly affect analysis accuracy.
#High Correlations: age is highly correlated with charges; charges is also highly correlated with age and 1 other field; smoker is highly correlated with charges.
# Zeros: The children column has 574 zeros, representing 42.9% of the dataset, indicating many entries with no children.

# %%
# OverView
#The dataset has 7 variables and 1338 observations with no missing values, ensuring data completeness. Only one duplicate row exists, which is about 0.1% of the dataset. The entire dataset takes up 286.5 KB in memory, with each record averaging 219.3 bytes. Among the variables, 4 are numeric, 2 are categorical, and 1 is boolean.

# %%
#BMI (Body Mass Index):
#BMI ranges from 15.96 to 53.13 with a mean of around 30.66, showing overweight on average.
#No missing, zero, or negative values.
#The histogram shows a normal-like distribution, centered around 25–35.

# %%
#Charges:
# Charges vary widely, from about 1,121 to 63,770, with a mean of 13,270.
# Almost all values are unique (99.9% distinct) and no missing data.
# Distribution is right-skewed, with most charges clustered at lower values and a few very high outliers.

# %%
#Children:
# Number of children ranges from 0 to 5, with a mean of about 1.1.
# Many people have 0 children (42.9%), making zeros the most common value.
# The histogram shows decreasing counts as the number of children increases.

# %%
#This is a correlation heatmap
# Age and Charges have a strong positive correlation (~0.3–0.4), meaning older people tend to pay higher insurance charges.
# Smoker and Charges show the strongest correlation (~0.75–0.8) — smoking greatly increases medical costs.
# BMI and Charges also correlate positively (~0.2–0.3), so higher BMI is linked with higher charges.
# Children, Region, and Sex show very weak correlations (close to 0), meaning they hardly affect charges directly.
# Diagonal values are all 1.0, since each variable is perfectly correlated with itself.
# The heatmap uses blue for positive and red for negative correlations, but here most are weakly positive.

#Smoker (≈ 0.8) → Being a smoker has the largest impact on insurance charges. Smokers pay significantly higher costs.
# Age (≈ 0.3–0.4) → Older individuals are likely to have higher medical expenses, so age is the second strongest factor.
# BMI (≈ 0.2–0.3) → Higher body mass index (BMI) moderately increases charges, linking obesity with higher medical risk.

# %%
#Chart
#This chart shows the relationship between age and number of children. Most people across all age groups have 0 to 2 children, with a higher density at younger ages having no children. As age increases, the distribution spreads, but still, very few people have more than 3–5 children. Overall, there is no strong direct correlation between age and number of children in this dataset.
