# %%
# importing the usual needed modules
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
insurance = pd.read_csv("insurance.csv")
insurance.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
from ydata_profiling import ProfileReport

report = ProfileReport(insurance, title='insurance Report', explorative=True)

report.to_file('insurance_report.html')
# Out:
#             <div>
#                 <ins><a href="https://ydata.ai/register">Upgrade to ydata-sdk</a></ins>
#                 <p>
#                     Improve your data and profiling with ydata-sdk, featuring data quality scoring, redundancy detection, outlier identification, text validation, and synthetic data generation.
#                 </p>
#             </div>
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/7 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# OptionError                               Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/ydata_profiling/utils/compat.py:28, in optional_option_context(option_key, value)
#      27 try:
# ---> 28     with pd.option_context(option_key, value):
#      29         yield
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/_config/config.py:442, in option_context.__enter__(self)
#     441 def __enter__(self) -> None:
# --> 442     self.undo = [(pat, _get_option(pat, silent=True)) for pat, val in self.ops]
#     444     for pat, val in self.ops:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/_config/config.py:442, in <listcomp>(.0)
#     441 def __enter__(self) -> None:
# --> 442     self.undo = [(pat, _get_option(pat, silent=True)) for pat, val in self.ops]
#     444     for pat, val in self.ops:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/_config/config.py:135, in _get_option(pat, silent)
#     134 def _get_option(pat: str, silent: bool = False) -> Any:
# --> 135     key = _get_single_key(pat, silent)
#     137     # walk the nested dict
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/_config/config.py:121, in _get_single_key(pat, silent)
#     120         _warn_if_deprecated(pat)
# --> 121     raise OptionError(f"No such keys(s): {repr(pat)}")
#     122 if len(keys) > 1:
#
# OptionError: No such keys(s): 'future.no_silent_downcasting'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 5
#       1 from ydata_profiling import ProfileReport
#       3 report = ProfileReport(insurance, title='insurance Report', explorative=True)
# ----> 5 report.to_file('insurance_report.html')
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/ydata_profiling/profile_report.py:381, in ProfileReport.to_file(self, output_file, silent)
#     378         self.config.html.assets_prefix = str(output_file.stem) + "_assets"
#     379     create_html_assets(self.config, output_file)
# --> 381 data = self.to_html()
#     383 if output_file.suffix != ".html":
#     384     suffix = output_file.suffix
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/ydata_profiling/profile_report.py:498, in ProfileReport.to_html(self)
#     490 def to_html(self) -> str:
#     491     """Generate and return complete template as lengthy string
#     492         for using with frameworks.
#     493
#    (...)
#     496
#     497     """
# --> 498     return self.html
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/ydata_profiling/profile_report.py:294, in ProfileReport.html(self)
#     291 @property
#     292 def html(self) -> str:
#     293     if self._html is None:
# --> 294         self._html = self._render_html()
#     295     return self._html
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/ydata_profiling/profile_report.py:411, in ProfileReport._render_html(self)
#     408 def _render_html(self) -> str:
#     409     from ydata_profiling.report.presentation.flavours import HTMLReport
# --> 411     report = self.report
#     413     with tqdm(
#     414         total=1, desc="Render HTML", disable=not self.config.progress_bar
#     415     ) as pbar:
#     416         html = HTMLReport(copy.deepcopy(report)).render(
#     417             nav=self.config.html.navbar_show,
#     418             offline=self.config.html.use_local_assets,
#    (...)
#     426             version=self.description_set.package["ydata_profiling_version"],
#     427         )
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/ydata_profiling/profile_report.py:288, in ProfileReport.report(self)
#     285 @property
#     286 def report(self) -> Root:
#     287     if self._report is None:
# --> 288         self._report = get_report_structure(self.config, self.description_set)
#     289     return self._report
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/ydata_profiling/profile_report.py:270, in ProfileReport.description_set(self)
#     267 @property
#     268 def description_set(self) -> BaseDescription:
#     269     if self._description_set is None:
# --> 270         self._description_set = describe_df(
#     271             self.config,
#     272             self.df,
#     273             self.summarizer,
#     274             self.typeset,
#     275             self._sample,
#     276         )
#     277     return self._description_set
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/ydata_profiling/model/describe.py:89, in describe(config, df, summarizer, typeset, sample)
#      87 # Variable-specific
#      88 pbar.total += len(df.columns)
# ---> 89 series_description = get_series_descriptions(
#      90     config, df, summarizer, typeset, pbar
#      91 )
#      93 pbar.set_postfix_str("Get variable types")
#      94 pbar.total += 1
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/ydata_profiling/model/summary.py:62, in get_series_descriptions(config, df, summarizer, typeset, pbar)
#      54 def get_series_descriptions(
#      55     config: Settings,
#      56     df: Any,
#    (...)
#      59     pbar: tqdm,
#      60 ) -> dict:
#      61     if isinstance(df, pd.DataFrame):
# ---> 62         return pandas_get_series_descriptions(config, df, summarizer, typeset, pbar)
#      63     elif isinstance(df, sparkDataFrame):  # type: ignore
#      64         return get_series_descriptions_spark(config, df, summarizer, typeset, pbar)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/ydata_profiling/model/pandas/summary_pandas.py:98, in pandas_get_series_descriptions(config, df, summarizer, typeset, pbar)
#      92     future_to_col = {
#      93         executor.submit(describe_column, name, series): name  # type:ignore
#      94         for name, series in df.items()
#      95     }
#      97     for future in tqdm(future_to_col.keys(), total=len(future_to_col)):
# ---> 98         name, description = future.result()
#      99         series_description[name] = description
#     101 return sort_column_names(series_description, config.sort)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/concurrent/futures/_base.py:451, in Future.result(self, timeout)
#     449     raise CancelledError()
#     450 elif self._state == FINISHED:
# --> 451     return self.__get_result()
#     453 self._condition.wait(timeout)
#     455 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/concurrent/futures/_base.py:403, in Future.__get_result(self)
#     401 if self._exception:
#     402     try:
# --> 403         raise self._exception
#     404     finally:
#     405         # Break a reference cycle with the exception in self._exception
#     406         self = None
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/concurrent/futures/thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/ydata_profiling/model/pandas/summary_pandas.py:81, in pandas_get_series_descriptions.<locals>.describe_column(name, series)
#      79 """Process a single series to get the column description."""
#      80 pbar.set_postfix_str(f"Describe variable: {name}")
# ---> 81 description = pandas_describe_1d(config, series, summarizer, typeset)
#      82 pbar.update()
#      83 return name, description
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/ydata_profiling/model/pandas/summary_pandas.py:43, in pandas_describe_1d(config, series, summarizer, typeset)
#      41 # Make sure pd.NA is not in the series
#      42 with optional_option_context("future.no_silent_downcasting", True):
# ---> 43     series = series.fillna(np.nan).infer_objects(copy=False)
#      45 has_cast_type = _is_cast_type_defined(typeset, series.name)  # type:ignore
#      46 cast_type = (
#      47     str(typeset.type_schema[series.name]) if has_cast_type else None
#      48 )  # type:ignore
#
# TypeError: NDFrame.infer_objects() got an unexpected keyword argument 'copy'

# %%
import webbrowser
webbrowser.open('insurance_report.html')
