# %%
# importing the usual needed modules
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
drug = pd.read_csv("drug.csv")
drug.head()
# Out:
#    Age Sex      BP Cholesterol  Na_to_K   Drug
# 0   23   F    HIGH        HIGH   25.355  DrugY
# 1   47   M     LOW        HIGH   13.093  drugC
# 2   47   M     LOW        HIGH   10.114  drugC
# 3   28   F  NORMAL        HIGH    7.798  drugX
# 4   61   F     LOW        HIGH   18.043  DrugY

# %%
from ydata_profiling import ProfileReport

report = ProfileReport(drug, title='drug Report', explorative=True)

report.to_file('drug_report.html')
# Out:
#             <div>
#                 <ins><a href="https://ydata.ai/register">Upgrade to ydata-sdk</a></ins>
#                 <p>
#                     Improve your data and profiling with ydata-sdk, featuring data quality scoring, redundancy detection, outlier identification, text validation, and synthetic data generation.
#                 </p>
#             </div>
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
import webbrowser
webbrowser.open('drug_report.html')
# Out:
# True

# %%
#This drug Report (generated by pandas-profiling/ProfileReport) shows 2 alerts:
# BP is highly overall correlated with Drug.
# Drug is highly overall correlated with BP.

# %%
#This ProfileReport overview shows the dataset has 6 variables and 200 observations.
#There are 0 missing cells (0.0%) and 0 duplicate rows (0.0%).
#The dataset size is 50.8 KiB with an average record size of 259.9 B.
#Variable types: 2 Numeric and 4 Categorical.

# %%
#Age is a numeric variable with values ranging from 15 to 74, mean 44.3, and 57 distinct values (28.5%) with no missing or zero entries.
# The BP (Blood Pressure) variable is categorical with 3 levels: HIGH (77), LOW (64), NORMAL (59), and no missing values.
# Age distribution is fairly spread across the range with no negatives or infinities, memory size 1.7 KiB.
# BP has balanced category counts, mean string length 4.27, and memory size 12.1 KiB.

# %%
#the scatter plot shows Age vs Na_to_K. The Age values range from about 15 to 75, while Na_to_K values range from about 6 to 38. The points are spread out randomly, showing no strong linear relationship between the two variables. This means Age and Na_to_K do not directly move together.

#the scatter plot shows Na_to_K vs Na_to_K. The values range from about 6.2 to 38.2, and all points lie perfectly on a diagonal line. This happens because the variable is plotted against itself, giving a one-to-one identity relationship.

# or in other words  All points form a perfect diagonal line because each Na_to_K value is exactly equal to itself. This confirms a one-to-one identity relationship between the two axes.

# %%
#The strongest positive correlation is between Na_to_K and Drug (~0.75), meaning higher sodium-to-potassium levels are strongly linked with the drug type.
# Age and BP (~0.40), and BP and Cholesterol (~0.45) also show moderate positive relationships.
# Cholesterol and Drug (~0.30), as well as Age and Na_to_K (~0.25), indicate weaker positive links.
# Sex has very low correlation with most variables, close to 0.0, meaning little to no linear relationship.There is a slight negative correlation between Age and Sex (~-0.10) and between Sex and Drug (~-0.05).
# Diagonal values are 1.00 because each variable is perfectly correlated with itself.

# %%
#This dataset has 6 columns: Age, Sex, BP, Cholesterol, Na_to_K, and Drug. For example, a 23-year-old female (BP=HIGH, Cholesterol=HIGH, Na_to_K=25.355) → DrugY, and a 47-year-old male (BP=LOW, Cholesterol=HIGH, Na_to_K=13.093) → drugC. Drugs include DrugY, drugC, and drugX, given based on conditions. A 61-year-old female (LOW BP, HIGH Cholesterol, Na_to_K=18.043) → DrugY, while a 22-year-old female (NORMAL BP, HIGH Cholesterol, Na_to_K=8.607) → drugX. Overall, the report studies patient counts per drug, gender split, BP & Cholesterol levels, average Age/Na_to_K per drug, and how these factors affect which drug is prescribed most often.
