# %%
# importing the usual needed modules
import pandas as pd
import numpy as np

# %%
insurance = pd.read_csv("insurance.csv")
insurance.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
import sweetviz as sv

# Analyzing the dataset
insurance_sweetviz_report = sv.analyze(insurance)

# Show the report in an HTML file
insurance_sweetviz_report.show_html("insurance_sweetviz_report.html")
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
# Report insurance_sweetviz_report.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
# The insurance dataset has about 1300 rows with features like age, sex, BMI, children, smoker status, region, and charges, and it contains no missing values, making it clean to use. Charges, the main variable, are skewed, with most people paying moderate amounts and a few paying very high. Age ranges from young adults to older people, BMI goes from healthy to obese, and children count varies across families. Categorical features such as sex, smoker, and region are evenly distributed, though there are more non-smokers than smokers.

# %%
# more over 
# The report shows that smokers have much higher insurance charges than non-smokers, making smoking the strongest driver of cost. Age and BMI also increase charges but not as strongly, while the number of children has only a small effect, and region or sex matter very little. A few people with very high BMI, age, or charges appear as outliers compared to the rest. Since the dataset is complete, no cleaning is needed, and analysis can focus on using key predictors like smoker status, age, and BMI, as well as grouping people by smoking habits, age ranges, or BMI levels for better insights.
